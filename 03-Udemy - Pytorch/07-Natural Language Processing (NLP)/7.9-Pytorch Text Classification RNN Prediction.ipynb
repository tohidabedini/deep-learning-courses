# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd
import torchtext
# import torchtext.data as ttd
import torchtext.legacy.data as ttd
from torchtext.vocab import GloVe
from sklearn.metrics import confusion_matrix
import itertools

# %matplotlib inline

# %% [markdown]
# ### Functions

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title="Confusion matrix", cmap=plt.cm.Blues):
    if normalize:
        cm=cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print("Confusion matrix, without normalization")
    print(cm)
    
    plt.imshow(cm, interpolation="nearest",cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = ".2f" if normalize else "d"
    thresh = cm.max()/2.
    
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j],fmt),
                 horizontalalignment="center",
                 color="white" if cm[i,j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.show()


def index_to_token(itos,sent):
    out = []
    for i in sent:
        out.append(itos[int(i)])

    return out


class RNN(nn.Module):
    def __init__(self, n_vocab, embed_dim, n_hidden, n_rnnlayers, n_outputs, model_type, device):
        super(RNN,self).__init__()
        self.V = n_vocab
        self.D = embed_dim
        self.M = n_hidden
        self.K = n_outputs
        self.L = n_rnnlayers
        self.model_type = model_type
        self.device = device
        
        self.embed = nn.Embedding(self.V, self.D)
        if self.model_type=="GRU":
            self.rnn = nn.GRU(
                input_size = self.D,
                hidden_size = self.M,
                num_layers = self.L,
                batch_first=True
            )
        elif self.model_type=="LSTM":
            self.rnn = nn.LSTM(
                input_size = self.D,
                hidden_size = self.M,
                num_layers = self.L,
                batch_first=True
            )
            
        self.fc = nn.Linear(self.M, self.K)
        
    def forward(self, X):
        h0 = torch.zeros(self.L, X.size(0), self.M).to(self.device)
        if self.model_type=="LSTM":
            c0 = torch.zeros(self.L, X.size(0), self.M).to(self.device)
            out = self.embed(X)
            out,_ = self.rnn(out, (h0,c0))
        elif self.model_type=="GRU":
            out = self.embed(X)
            out,_ = self.rnn(out, h0)
        
        out,_ = torch.max(out, 1)
        out = self.fc(out)
        return out



def create_model_and_train(train_iter,test_iter,V,D,M,L,K,n_epochs=100,model_type="LSTM"):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(device)
    
    if model_type=="GRU":
        model = RNN(n_vocab=V ,embed_dim=D, n_hidden=M, n_rnnlayers=L, n_outputs=K, model_type=model_type, device=device)
    elif model_type=="LSTM":
        model = RNN(n_vocab=V ,embed_dim=D, n_hidden=M, n_rnnlayers=L, n_outputs=K, model_type=model_type, device=device)


    model.to(device)
    
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters())
    
    train_losses = np.zeros(n_epochs)
    test_losses  = np.zeros(n_epochs)
    
    for it in range(n_epochs):
        t0 = datetime.now()
        train_loss = []
        for inputs,targets in train_iter:
            targets = targets.view(-1,1).float()
            optimizer.zero_grad()
        
            outputs = model(inputs)
            loss = criterion(outputs, targets)
        
            loss.backward()
            optimizer.step()
            train_loss.append(loss.item())
        
        train_losses[it] = np.mean(train_loss)


        test_loss = []
        for inputs,targets in test_iter:
            targets = targets.view(-1,1).float()
        
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss.append(loss.item())
        
        test_losses[it] = np.mean(test_loss)

        dt = datetime.now() - t0

        if (it+1)%5==0:

            print(f"Epoch {it+1}/{n_epochs}, Train Loss: {train_losses[it]:.4f}, Test Loss: {test_losses[it]:.4f}")
        
    return model,train_losses, test_losses


def plot_metric(data, metric):
    plt.plot(data, label=metric)
    plt.legend()
    plt.show


def acc_compouter(model,device,data_loader):
    n_correct=0.
    n_total=0.
    y_test = []
    p_test = []
    for inputs,targets in data_loader:
        # inputs,targets = inputs.to(device), targets.to(device)
        targets = targets.view(-1,1).float()

        outputs = model(inputs)
        
        predictions = (outputs>0)

        y_test += list(targets.cpu().numpy())
        # p_test += predictions
        p_test += list(predictions.cpu().numpy())
        
        
        n_correct += (predictions == targets).sum().item()
        # .item() from torch to simple python data type
        n_total += targets.shape[0]
        
    acc = n_correct/n_total

    return acc, y_test, p_test

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv("./spam.csv", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#      v1  ... Unnamed: 4
# 0   ham  ...        NaN
# 1   ham  ...        NaN
# 2  spam  ...        NaN
# 3   ham  ...        NaN
# 4   ham  ...        NaN
#
# [5 rows x 5 columns]

# %%
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.columns = ["labels", "data"]

# %%
df["b_labels"] = df["labels"].map({"ham":0, "spam":1})

# %%
df2 = df[["data","b_labels"]]

# %%
df2.head()
# Out:
#                                                 data  b_labels
# 0  Go until jurong point, crazy.. Available only ...         0
# 1                      Ok lar... Joking wif u oni...         0
# 2  Free entry in 2 a wkly comp to win FA Cup fina...         1
# 3  U dun say so early hor... U c already then say...         0
# 4  Nah I don't think he goes to usf, he lives aro...         0

# %%
df2.to_csv("spam2.csv", index=False)

# %%
TEXT = ttd.Field(
    sequential = True,
    batch_first = True,
    lower = True,
    # tokenize = 'spacy',
    pad_first = True
)
LABEL = ttd.Field(sequential = False, use_vocab = False, is_target = True)

# %%
dataset = ttd.TabularDataset(
    path = 'spam2.csv',
    format = 'csv',
    skip_header = True,
    fields = [('data',TEXT),('label',LABEL)]
)

# %%
# ex = dataset.examples[0]
# type(ex)
# ex.data
# ex.label

# %%
train_dataset , test_dataset = dataset.split() # default 0.7

# %%
TEXT.build_vocab(train_dataset)

# %%
vocab = TEXT.vocab

# %%
torchtext.vocab.Vocab
# Out:
# torchtext.vocab.Vocab

# %%
vocab.stoi
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.legacy.vocab.Vocab object at 0x7f47696f2fd0>>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              'to': 2,
#              'i': 3,
#              'you': 4,
#              'a': 5,
#              'the': 6,
#              'u': 7,
#              'and': 8,
#              'in': 9,
#              'is': 10,
#              'my': 11,
#              'for': 12,
#              'your': 13,
#              'of': 14,
#              'me': 15,
#              'have': 16,
#              'call': 17,
#              'on': 18,
#              'are': 19,
#              'it': 20,
#              'that': 21,
#              '2': 22,
#              'so': 23,
#              'but': 24,
#              'at': 25,
#              'or': 26,
#              'not': 27,
#              'can': 28,
#              "i'm": 29,
#              'ur': 30,
#              'get': 31,
#              'with': 32,
#              'if': 33,
#              'will': 34,
#              'just': 35,
#              'be': 36,
#              'we': 37,
#              'do': 38,
#              'this': 39,
#              '&lt;#&gt;': 40,
#              'from': 41,
#              'when': 42,
#              'go': 43,
#              'all': 44,
#              'now': 45,
#              '4': 46,
#              'no': 47,
#              'how': 48,
#              'got': 49,
#              'up': 50,
#              'what': 51,
#              'like': 52,
#              'know': 53,
#              'out': 54,
#              'was': 55,
#              'am': 56,
#              'then': 57,
#              'free': 58,
#              'come': 59,
#              'its': 60,
#              '.': 61,
#              'only': 62,
#              'good': 63,
#              'send': 64,
#              'time': 65,
#              'as': 66,
#              'text': 67,
#              'by': 68,
#              'he': 69,
#              '?': 70,
#              "i'll": 71,
#              'want': 72,
#              'going': 73,
#              'r': 74,
#              'txt': 75,
#              'still': 76,
#              'our': 77,
#              'about': 78,
#              'ok': 79,
#              'see': 80,
#              'love': 81,
#              'n': 82,
#              'one': 83,
#              'new': 84,
#              'she': 85,
#              'dont': 86,
#              'there': 87,
#              "don't": 88,
#              'need': 89,
#              'been': 90,
#              'has': 91,
#              '...': 92,
#              'mobile': 93,
#              'stop': 94,
#              'tell': 95,
#              'any': 96,
#              'they': 97,
#              'reply': 98,
#              'take': 99,
#              'think': 100,
#              'back': 101,
#              'please': 102,
#              '&': 103,
#              'claim': 104,
#              'home': 105,
#              'later': 106,
#              'ì_': 107,
#              'an': 108,
#              'day': 109,
#              'did': 110,
#              'hope': 111,
#              'now.': 112,
#              'who': 113,
#              'had': 114,
#              'me.': 115,
#              'hi': 116,
#              'some': 117,
#              'great': 118,
#              'happy': 119,
#              'her': 120,
#              "it's": 121,
#              'make': 122,
#              'phone': 123,
#              'more': 124,
#              '&amp;': 125,
#              'give': 126,
#              'pls': 127,
#              'well': 128,
#              'da': 129,
#              'here': 130,
#              'should': 131,
#              'after': 132,
#              'd': 133,
#              'him': 134,
#              'where': 135,
#              'dear': 136,
#              'c': 137,
#              'much': 138,
#              'sorry': 139,
#              'ask': 140,
#              'e': 141,
#              '-': 142,
#              'hey': 143,
#              'im': 144,
#              'night': 145,
#              'very': 146,
#              'why': 147,
#              'contact': 148,
#              'really': 149,
#              'say': 150,
#              'work': 151,
#              'you.': 152,
#              'meet': 153,
#              'now!': 154,
#              'too': 155,
#              'let': 156,
#              'cos': 157,
#              'doing': 158,
#              'it.': 159,
#              'pick': 160,
#              'oh': 161,
#              'today': 162,
#              "i've": 163,
#              'last': 164,
#              'number': 165,
#              'yeah': 166,
#              'right': 167,
#              'win': 168,
#              '1': 169,
#              'find': 170,
#              'sorry,': 171,
#              'week': 172,
#              'were': 173,
#              'buy': 174,
#              'cant': 175,
#              'said': 176,
#              'would': 177,
#              'also': 178,
#              'b': 179,
#              "can't": 180,
#              'feel': 181,
#              'miss': 182,
#              'prize': 183,
#              'way': 184,
#              'won': 185,
#              'keep': 186,
#              'lor.': 187,
#              'nokia': 188,
#              'gonna': 189,
#              'cash': 190,
#              'every': 191,
#              'message': 192,
#              'next': 193,
#              'sent': 194,
#              '3': 195,
#              'anything': 196,
#              'lol': 197,
#              'lor...': 198,
#              'sure': 199,
#              "that's": 200,
#              'us': 201,
#              'his': 202,
#              'msg': 203,
#              'per': 204,
#              'tomorrow': 205,
#              'wait': 206,
#              'wat': 207,
#              ':)': 208,
#              'around': 209,
#              'even': 210,
#              'thanks': 211,
#              'which': 212,
#              'care': 213,
#              'many': 214,
#              'them': 215,
#              'went': 216,
#              'ìï': 217,
#              'could': 218,
#              'down': 219,
#              'dun': 220,
#              'someone': 221,
#              'yes': 222,
#              'before': 223,
#              'chat': 224,
#              'first': 225,
#              'never': 226,
#              'place': 227,
#              'service': 228,
#              'something': 229,
#              'thought': 230,
#              'wan': 231,
#              '!': 232,
#              'always': 233,
#              'day.': 234,
#              'ok.': 235,
#              'thk': 236,
#              "you're": 237,
#              'getting': 238,
#              'having': 239,
#              'ill': 240,
#              'over': 241,
#              'told': 242,
#              'already': 243,
#              'customer': 244,
#              'draw': 245,
#              'gud': 246,
#              'money': 247,
#              'morning': 248,
#              'off': 249,
#              'other': 250,
#              'urgent!': 251,
#              'waiting': 252,
#              'being': 253,
#              'late': 254,
#              'talk': 255,
#              'than': 256,
#              'wish': 257,
#              'x': 258,
#              'you!': 259,
#              'life': 260,
#              'same': 261,
#              'thing': 262,
#              'tone': 263,
#              'trying': 264,
#              'use': 265,
#              'awarded': 266,
#              'people': 267,
#              'sleep': 268,
#              'try': 269,
#              'ya': 270,
#              'babe': 271,
#              'best': 272,
#              'better': 273,
#              'leave': 274,
#              'mins': 275,
#              'things': 276,
#              'y': 277,
#              'bit': 278,
#              'coming': 279,
#              'da.': 280,
#              'dat': 281,
#              'eat': 282,
#              'friends': 283,
#              'holiday': 284,
#              'no.': 285,
#              'receive': 286,
#              'wanna': 287,
#              '1st': 288,
#              'few': 289,
#              'home.': 290,
#              'k': 291,
#              'may': 292,
#              'thats': 293,
#              'u.': 294,
#              '150ppm': 295,
#              'account': 296,
#              'another': 297,
#              "didn't": 298,
#              'help': 299,
#              'live': 300,
#              'long': 301,
#              'nice': 302,
#              'shows': 303,
#              'stuff': 304,
#              'year': 305,
#              'å£1000': 306,
#              '*': 307,
#              'enjoy': 308,
#              'finish': 309,
#              'guys': 310,
#              'latest': 311,
#              'meeting': 312,
#              'part': 313,
#              'shall': 314,
#              'sms': 315,
#              'there.': 316,
#              'those': 317,
#              'watching': 318,
#              'you,': 319,
#              'yup': 320,
#              'again': 321,
#              'asked': 322,
#              'box': 323,
#              'bring': 324,
#              'check': 325,
#              'cost': 326,
#              'days': 327,
#              'done': 328,
#              'guess': 329,
#              'heart': 330,
#              'jus': 331,
#              'made': 332,
#              'name': 333,
#              'ok...': 334,
#              'quite': 335,
#              'shopping': 336,
#              'smile': 337,
#              '2nd': 338,
#              'actually': 339,
#              'didnt': 340,
#              'face': 341,
#              'friend': 342,
#              'i.ll': 343,
#              'into': 344,
#              'look': 345,
#              'lunch': 346,
#              'man': 347,
#              'maybe': 348,
#              'pay': 349,
#              'person': 350,
#              'play': 351,
#              'po': 352,
#              'probably': 353,
#              'put': 354,
#              'reach': 355,
#              'soon': 356,
#              'special': 357,
#              'because': 358,
#              'called': 359,
#              'chance': 360,
#              'god': 361,
#              "how's": 362,
#              'little': 363,
#              'now?': 364,
#              'selected': 365,
#              'time.': 366,
#              'v': 367,
#              'watch': 368,
#              'without': 369,
#              'yo': 370,
#              'you?': 371,
#              'able': 372,
#              'attempt': 373,
#              'den': 374,
#              'dunno': 375,
#              'fun': 376,
#              'half': 377,
#              'job': 378,
#              'makes': 379,
#              'might': 380,
#              'minutes': 381,
#              'ready': 382,
#              'real': 383,
#              'remember': 384,
#              'since': 385,
#              'tonight': 386,
#              'wanted': 387,
#              ',': 388,
#              '18': 389,
#              'big': 390,
#              'birthday': 391,
#              'camera': 392,
#              'car': 393,
#              'class': 394,
#              'dad': 395,
#              'dis': 396,
#              'does': 397,
#              'end': 398,
#              'entry': 399,
#              'fuck': 400,
#              'guaranteed': 401,
#              "he's": 402,
#              'hear': 403,
#              'looking': 404,
#              'orange': 405,
#              'speak': 406,
#              'till': 407,
#              'two': 408,
#              'until': 409,
#              'video': 410,
#              'wif': 411,
#              'word': 412,
#              '5': 413,
#              'abt': 414,
#              'double': 415,
#              'ever': 416,
#              'forgot': 417,
#              'girl': 418,
#              'hav': 419,
#              'left': 420,
#              'lot': 421,
#              'luv': 422,
#              'most': 423,
#              'must': 424,
#              'once': 425,
#              'sweet': 426,
#              'thank': 427,
#              'til': 428,
#              'today.': 429,
#              'valid': 430,
#              'wake': 431,
#              'weekly': 432,
#              'while': 433,
#              'wont': 434,
#              'world': 435,
#              '6': 436,
#              'bad': 437,
#              'between': 438,
#              'boy': 439,
#              'bt': 440,
#              'came': 441,
#              'dinner': 442,
#              'everything': 443,
#              'goes': 444,
#              'haf': 445,
#              'haha': 446,
#              'join': 447,
#              'lor': 448,
#              'means': 449,
#              'min': 450,
#              'mind': 451,
#              'nothing': 452,
#              'plus': 453,
#              'run': 454,
#              'says': 455,
#              'that.': 456,
#              'u?': 457,
#              'working': 458,
#              'xxx': 459,
#              'å£100': 460,
#              '+': 461,
#              '16+': 462,
#              'ard': 463,
#              'babe,': 464,
#              'believe': 465,
#              'bonus': 466,
#              'collect': 467,
#              'details': 468,
#              'drive': 469,
#              'either': 470,
#              'enough': 471,
#              'free!': 472,
#              'good.': 473,
#              'hour': 474,
#              'network': 475,
#              'ringtone': 476,
#              'room': 477,
#              'sat': 478,
#              'set': 479,
#              'sexy': 480,
#              'shit': 481,
#              'tones': 482,
#              'tried': 483,
#              "won't": 484,
#              '4*': 485,
#              '500': 486,
#              'bus': 487,
#              'cause': 488,
#              'coz': 489,
#              'do.': 490,
#              'finished': 491,
#              'gift': 492,
#              'hot': 493,
#              'house': 494,
#              'liao...': 495,
#              'me?': 496,
#              'post': 497,
#              'saw': 498,
#              'show': 499,
#              'sir,': 500,
#              'start': 501,
#              'stay': 502,
#              'stop.': 503,
#              't&cs': 504,
#              "there's": 505,
#              'these': 506,
#              'town': 507,
#              'tv': 508,
#              "we're": 509,
#              "what's": 510,
#              'wot': 511,
#              'xmas': 512,
#              'yet': 513,
#              '08000839402': 514,
#              '150p': 515,
#              '16': 516,
#              '8007': 517,
#              '86688': 518,
#              'address': 519,
#              'away': 520,
#              'book': 521,
#              'close': 522,
#              'code': 523,
#              'early': 524,
#              'feeling': 525,
#              'forget': 526,
#              'full': 527,
#              'goin': 528,
#              'guaranteed.': 529,
#              'guy': 530,
#              'hair': 531,
#              'havent': 532,
#              'later.': 533,
#              'mail': 534,
#              'making': 535,
#              'missing': 536,
#              'music': 537,
#              'needs': 538,
#              'plan': 539,
#              'pounds': 540,
#              'price': 541,
#              're': 542,
#              "she's": 543,
#              'takes': 544,
#              'texts': 545,
#              'today?': 546,
#              'todays': 547,
#              'together': 548,
#              'too.': 549,
#              'u!': 550,
#              'wants': 551,
#              "we'll": 552,
#              'wen': 553,
#              'wid': 554,
#              'yeah,': 555,
#              'years': 556,
#              'å£2000': 557,
#              '7': 558,
#              '750': 559,
#              ':-)': 560,
#              'aft': 561,
#              'aight': 562,
#              'already?': 563,
#              'await': 564,
#              'baby': 565,
#              'bed': 566,
#              'both': 567,
#              'calling': 568,
#              'comes': 569,
#              'decided': 570,
#              'evening': 571,
#              'expires': 572,
#              'hello': 573,
#              'it,': 574,
#              'kind': 575,
#              'land': 576,
#              'line.': 577,
#              'lose': 578,
#              'lots': 579,
#              'message.': 580,
#              'missed': 581,
#              'mobileupd8': 582,
#              'month': 583,
#              'neva': 584,
#              'offer': 585,
#              'pain': 586,
#              'pics': 587,
#              'plz': 588,
#              'princess!': 589,
#              'right?': 590,
#              'ring': 591,
#              'saying': 592,
#              'secret': 593,
#              'smoke': 594,
#              'sounds': 595,
#              'started': 596,
#              'taking': 597,
#              'tmr': 598,
#              'tomorrow.': 599,
#              'tonight?': 600,
#              'top': 601,
#              'trip': 602,
#              'type': 603,
#              'unsubscribe': 604,
#              'up.': 605,
#              'update': 606,
#              'vouchers': 607,
#              'walk': 608,
#              'week.': 609,
#              'wit': 610,
#              'work.': 611,
#              '12hrs': 612,
#              'anyway': 613,
#              'apply': 614,
#              'available': 615,
#              'beautiful': 616,
#              'calls': 617,
#              'carlos': 618,
#              'change': 619,
#              'congratulations': 620,
#              'date': 621,
#              'dating': 622,
#              "doesn't": 623,
#              'drop': 624,
#              'fine': 625,
#              "haven't": 626,
#              'head': 627,
#              'hours': 628,
#              'identifier': 629,
#              'important': 630,
#              'it?': 631,
#              'juz': 632,
#              'lar...': 633,
#              'leaving': 634,
#              'lucky': 635,
#              'mean': 636,
#              'messages': 637,
#              'mob': 638,
#              'oh.': 639,
#              'only.': 640,
#              'out.': 641,
#              'points.': 642,
#              'question': 643,
#              's': 644,
#              'school': 645,
#              'sister': 646,
#              'telling': 647,
#              'test': 648,
#              'th': 649,
#              'thanx': 650,
#              'thinking': 651,
#              'tot': 652,
#              'å£500': 653,
#              'å£5000': 654,
#              '&lt;decimal&gt;': 655,
#              'already.': 656,
#              'alright': 657,
#              'answer': 658,
#              'bank': 659,
#              'bored': 660,
#              'break': 661,
#              'caller': 662,
#              'care.': 663,
#              'collection.': 664,
#              'company': 665,
#              'drink': 666,
#              'each': 667,
#              'fancy': 668,
#              'final': 669,
#              'fr': 670,
#              'gr8': 671,
#              'her.': 672,
#              'hold': 673,
#              'id': 674,
#              'it!': 675,
#              'knew': 676,
#              'landline.': 677,
#              'least': 678,
#              'lets': 679,
#              'line': 680,
#              'lovely': 681,
#              'nite': 682,
#              'noe': 683,
#              'now,': 684,
#              'oso': 685,
#              'private!': 686,
#              'problem': 687,
#              'search': 688,
#              'shop': 689,
#              'somebody': 690,
#              'statement': 691,
#              't&c': 692,
#              'thinks': 693,
#              'true': 694,
#              'visit': 695,
#              'weekend': 696,
#              'wonderful': 697,
#              'yourself': 698,
#              'å£1.50': 699,
#              '10': 700,
#              '10p': 701,
#              '18+': 702,
#              '2.': 703,
#              '2003': 704,
#              '4.': 705,
#              '800': 706,
#              '87066': 707,
#              'ah?': 708,
#              'angry': 709,
#              'anytime': 710,
#              'back.': 711,
#              'bout': 712,
#              'busy': 713,
#              'checking': 714,
#              'choose': 715,
#              'class.': 716,
#              'code:': 717,
#              'colour': 718,
#              'cool,': 719,
#              'currently': 720,
#              'delivery': 721,
#              'driving': 722,
#              'easy': 723,
#              'easy,': 724,
#              'empty': 725,
#              'eve': 726,
#              'everyone': 727,
#              'fone': 728,
#              'food': 729,
#              'found': 730,
#              'frm': 731,
#              'frnd': 732,
#              'g': 733,
#              'gone': 734,
#              'hard': 735,
#              'hows': 736,
#              'know.': 737,
#              'landline': 738,
#              'loads': 739,
#              'me,': 740,
#              'morning.': 741,
#              'movie': 742,
#              'mu': 743,
#              'national': 744,
#              'no:': 745,
#              'office': 746,
#              'operator': 747,
#              'opt': 748,
#              'order': 749,
#              'outside': 750,
#              'pa.': 751,
#              'pobox': 752,
#              'poly': 753,
#              'prize.': 754,
#              'rate': 755,
#              'sad': 756,
#              'sae': 757,
#              'sch': 758,
#              'sex': 759,
#              'story': 760,
#              'their': 761,
#              'this.': 762,
#              'though': 763,
#              'un-redeemed': 764,
#              'urgent': 765,
#              'used': 766,
#              'valued': 767,
#              'week!': 768,
#              'yes,': 769,
#              '!!': 770,
#              '..': 771,
#              '08000930705': 772,
#              '8': 773,
#              ':-(': 774,
#              'abiola': 775,
#              'afternoon': 776,
#              'alone': 777,
#              'already...': 778,
#              'apply.': 779,
#              'askd': 780,
#              'b4': 781,
#              'bath': 782,
#              'brother': 783,
#              'club': 784,
#              'cool.': 785,
#              'darren': 786,
#              'dear.': 787,
#              'dnt': 788,
#              'email': 789,
#              'entered': 790,
#              'extra': 791,
#              'felt': 792,
#              'finally': 793,
#              'fine.': 794,
#              'free.': 795,
#              'fucking': 796,
#              'gotta': 797,
#              'great!': 798,
#              'great.': 799,
#              'ha': 800,
#              'happen': 801,
#              'help.': 802,
#              'hurt': 803,
#              "i'd": 804,
#              'in.': 805,
#              'invited': 806,
#              'k,': 807,
#              'leh...': 808,
#              'log': 809,
#              'lost': 810,
#              'me..': 811,
#              'mine': 812,
#              'mm': 813,
#              'month.': 814,
#              'msgs': 815,
#              'mum': 816,
#              'myself': 817,
#              'nt': 818,
#              'ok?': 819,
#              'okay': 820,
#              'one.': 821,
#              'open': 822,
#              'pass': 823,
#              'poor': 824,
#              'project': 825,
#              'second': 826,
#              'seeing': 827,
#              'sell': 828,
#              'services': 829,
#              'she.s': 830,
#              'sis': 831,
#              'sleeping': 832,
#              'st': 833,
#              'starts': 834,
#              'sun': 835,
#              'support': 836,
#              'touch': 837,
#              'txts': 838,
#              'u,': 839,
#              'w': 840,
#              'weeks': 841,
#              'wil': 842,
#              'wkly': 843,
#              'words': 844,
#              'worry': 845,
#              'worth': 846,
#              'write': 847,
#              'xx': 848,
#              'yar': 849,
#              'yesterday': 850,
#              'yours.': 851,
#              '\x89û_': 852,
#              'å£2,000': 853,
#              'å£250': 854,
#              '1.': 855,
#              '100': 856,
#              '3.': 857,
#              '=': 858,
#              'age': 859,
#              'aight,': 860,
#              'area': 861,
#              'award.': 862,
#              'awesome,': 863,
#              'booked': 864,
#              'call.': 865,
#              'callertune': 866,
#              'catch': 867,
#              'cd': 868,
#              'charged': 869,
#              'chennai': 870,
#              'college': 871,
#              'complimentary': 872,
#              'convey': 873,
#              'couple': 874,
#              'crazy': 875,
#              'darlin': 876,
#              'de': 877,
#              'difficult': 878,
#              'doin': 879,
#              'don': 880,
#              'dream': 881,
#              'else': 882,
#              'family': 883,
#              'feels': 884,
#              'friendship': 885,
#              'frnds': 886,
#              'gas': 887,
#              'girls': 888,
#              'haha...': 889,
#              'happened': 890,
#              'heard': 891,
#              'hit': 892,
#              'however': 893,
#              'huh': 894,
#              "joy's": 895,
#              'kiss': 896,
#              'knows': 897,
#              'life.': 898,
#              'light': 899,
#              'love.': 900,
#              'match': 901,
#              'mayb': 902,
#              'medical': 903,
#              'min.': 904,
#              'night.': 905,
#              'night?': 906,
#              'normal': 907,
#              'number.': 908,
#              'numbers': 909,
#              'o': 910,
#              'ok,': 911,
#              'old': 912,
#              'pa': 913,
#              'party': 914,
#              'pic': 915,
#              'pm': 916,
#              'prize!': 917,
#              'rates': 918,
#              'reached': 919,
#              'read': 920,
#              'reading': 921,
#              'reason': 922,
#              'rply': 923,
#              's.': 924,
#              'safe': 925,
#              'seen': 926,
#              'simple..': 927,
#              'song': 928,
#              'sorry.': 929,
#              'swing': 930,
#              'ten': 931,
#              'thanx...': 932,
#              'then.': 933,
#              'thinkin': 934,
#              'through': 935,
#              'times': 936,
#              'tired': 937,
#              'took': 938,
#              'train': 939,
#              'treat': 940,
#              'truth': 941,
#              'wat...': 942,
#              'wat?': 943,
#              'well,': 944,
#              'well.': 945,
#              'whats': 946,
#              'whenever': 947,
#              'wine': 948,
#              'within': 949,
#              'year.': 950,
#              'yet.': 951,
#              'yr': 952,
#              '&lt;time&gt;': 953,
#              '*grins*': 954,
#              '0800': 955,
#              '11': 956,
#              '150p/msg': 957,
#              ':': 958,
#              'admirer': 959,
#              'again!': 960,
#              'again.': 961,
#              'against': 962,
#              'ans': 963,
#              'asking': 964,
#              'auction': 965,
#              'bluetooth': 966,
#              'boytoy': 967,
#              'case': 968,
#              'charge': 969,
#              'charity': 970,
#              'comp': 971,
#              'completely': 972,
#              'computer': 973,
#              'congrats!': 974,
#              'content': 975,
#              'cool': 976,
#              'copy': 977,
#              'cum': 978,
#              'cut': 979,
#              'day,': 980,
#              'decide': 981,
#              'del': 982,
#              'din': 983,
#              'direct': 984,
#              'dogging': 985,
#              'doing.': 986,
#              'doing?': 987,
#              'dreams': 988,
#              'dude': 989,
#              'eg': 990,
#              'eh': 991,
#              'em': 992,
#              'enter': 993,
#              'exam': 994,
#              'far': 995,
#              'film': 996,
#              'fine,': 997,
#              'following': 998,
#              'gave': 999,
#              ...})

# %%
vocab.itos
# Out:
# ['<unk>',
#  '<pad>',
#  'to',
#  'i',
#  'you',
#  'a',
#  'the',
#  'u',
#  'and',
#  'in',
#  'is',
#  'my',
#  'for',
#  'your',
#  'of',
#  'me',
#  'have',
#  'call',
#  'on',
#  'are',
#  'it',
#  'that',
#  '2',
#  'so',
#  'but',
#  'at',
#  'or',
#  'not',
#  'can',
#  "i'm",
#  'ur',
#  'get',
#  'with',
#  'if',
#  'will',
#  'just',
#  'be',
#  'we',
#  'do',
#  'this',
#  '&lt;#&gt;',
#  'from',
#  'when',
#  'go',
#  'all',
#  'now',
#  '4',
#  'no',
#  'how',
#  'got',
#  'up',
#  'what',
#  'like',
#  'know',
#  'out',
#  'was',
#  'am',
#  'then',
#  'free',
#  'come',
#  'its',
#  '.',
#  'only',
#  'good',
#  'send',
#  'time',
#  'as',
#  'text',
#  'by',
#  'he',
#  '?',
#  "i'll",
#  'want',
#  'going',
#  'r',
#  'txt',
#  'still',
#  'our',
#  'about',
#  'ok',
#  'see',
#  'love',
#  'n',
#  'one',
#  'new',
#  'she',
#  'dont',
#  'there',
#  "don't",
#  'need',
#  'been',
#  'has',
#  '...',
#  'mobile',
#  'stop',
#  'tell',
#  'any',
#  'they',
#  'reply',
#  'take',
#  'think',
#  'back',
#  'please',
#  '&',
#  'claim',
#  'home',
#  'later',
#  'ì_',
#  'an',
#  'day',
#  'did',
#  'hope',
#  'now.',
#  'who',
#  'had',
#  'me.',
#  'hi',
#  'some',
#  'great',
#  'happy',
#  'her',
#  "it's",
#  'make',
#  'phone',
#  'more',
#  '&amp;',
#  'give',
#  'pls',
#  'well',
#  'da',
#  'here',
#  'should',
#  'after',
#  'd',
#  'him',
#  'where',
#  'dear',
#  'c',
#  'much',
#  'sorry',
#  'ask',
#  'e',
#  '-',
#  'hey',
#  'im',
#  'night',
#  'very',
#  'why',
#  'contact',
#  'really',
#  'say',
#  'work',
#  'you.',
#  'meet',
#  'now!',
#  'too',
#  'let',
#  'cos',
#  'doing',
#  'it.',
#  'pick',
#  'oh',
#  'today',
#  "i've",
#  'last',
#  'number',
#  'yeah',
#  'right',
#  'win',
#  '1',
#  'find',
#  'sorry,',
#  'week',
#  'were',
#  'buy',
#  'cant',
#  'said',
#  'would',
#  'also',
#  'b',
#  "can't",
#  'feel',
#  'miss',
#  'prize',
#  'way',
#  'won',
#  'keep',
#  'lor.',
#  'nokia',
#  'gonna',
#  'cash',
#  'every',
#  'message',
#  'next',
#  'sent',
#  '3',
#  'anything',
#  'lol',
#  'lor...',
#  'sure',
#  "that's",
#  'us',
#  'his',
#  'msg',
#  'per',
#  'tomorrow',
#  'wait',
#  'wat',
#  ':)',
#  'around',
#  'even',
#  'thanks',
#  'which',
#  'care',
#  'many',
#  'them',
#  'went',
#  'ìï',
#  'could',
#  'down',
#  'dun',
#  'someone',
#  'yes',
#  'before',
#  'chat',
#  'first',
#  'never',
#  'place',
#  'service',
#  'something',
#  'thought',
#  'wan',
#  '!',
#  'always',
#  'day.',
#  'ok.',
#  'thk',
#  "you're",
#  'getting',
#  'having',
#  'ill',
#  'over',
#  'told',
#  'already',
#  'customer',
#  'draw',
#  'gud',
#  'money',
#  'morning',
#  'off',
#  'other',
#  'urgent!',
#  'waiting',
#  'being',
#  'late',
#  'talk',
#  'than',
#  'wish',
#  'x',
#  'you!',
#  'life',
#  'same',
#  'thing',
#  'tone',
#  'trying',
#  'use',
#  'awarded',
#  'people',
#  'sleep',
#  'try',
#  'ya',
#  'babe',
#  'best',
#  'better',
#  'leave',
#  'mins',
#  'things',
#  'y',
#  'bit',
#  'coming',
#  'da.',
#  'dat',
#  'eat',
#  'friends',
#  'holiday',
#  'no.',
#  'receive',
#  'wanna',
#  '1st',
#  'few',
#  'home.',
#  'k',
#  'may',
#  'thats',
#  'u.',
#  '150ppm',
#  'account',
#  'another',
#  "didn't",
#  'help',
#  'live',
#  'long',
#  'nice',
#  'shows',
#  'stuff',
#  'year',
#  'å£1000',
#  '*',
#  'enjoy',
#  'finish',
#  'guys',
#  'latest',
#  'meeting',
#  'part',
#  'shall',
#  'sms',
#  'there.',
#  'those',
#  'watching',
#  'you,',
#  'yup',
#  'again',
#  'asked',
#  'box',
#  'bring',
#  'check',
#  'cost',
#  'days',
#  'done',
#  'guess',
#  'heart',
#  'jus',
#  'made',
#  'name',
#  'ok...',
#  'quite',
#  'shopping',
#  'smile',
#  '2nd',
#  'actually',
#  'didnt',
#  'face',
#  'friend',
#  'i.ll',
#  'into',
#  'look',
#  'lunch',
#  'man',
#  'maybe',
#  'pay',
#  'person',
#  'play',
#  'po',
#  'probably',
#  'put',
#  'reach',
#  'soon',
#  'special',
#  'because',
#  'called',
#  'chance',
#  'god',
#  "how's",
#  'little',
#  'now?',
#  'selected',
#  'time.',
#  'v',
#  'watch',
#  'without',
#  'yo',
#  'you?',
#  'able',
#  'attempt',
#  'den',
#  'dunno',
#  'fun',
#  'half',
#  'job',
#  'makes',
#  'might',
#  'minutes',
#  'ready',
#  'real',
#  'remember',
#  'since',
#  'tonight',
#  'wanted',
#  ',',
#  '18',
#  'big',
#  'birthday',
#  'camera',
#  'car',
#  'class',
#  'dad',
#  'dis',
#  'does',
#  'end',
#  'entry',
#  'fuck',
#  'guaranteed',
#  "he's",
#  'hear',
#  'looking',
#  'orange',
#  'speak',
#  'till',
#  'two',
#  'until',
#  'video',
#  'wif',
#  'word',
#  '5',
#  'abt',
#  'double',
#  'ever',
#  'forgot',
#  'girl',
#  'hav',
#  'left',
#  'lot',
#  'luv',
#  'most',
#  'must',
#  'once',
#  'sweet',
#  'thank',
#  'til',
#  'today.',
#  'valid',
#  'wake',
#  'weekly',
#  'while',
#  'wont',
#  'world',
#  '6',
#  'bad',
#  'between',
#  'boy',
#  'bt',
#  'came',
#  'dinner',
#  'everything',
#  'goes',
#  'haf',
#  'haha',
#  'join',
#  'lor',
#  'means',
#  'min',
#  'mind',
#  'nothing',
#  'plus',
#  'run',
#  'says',
#  'that.',
#  'u?',
#  'working',
#  'xxx',
#  'å£100',
#  '+',
#  '16+',
#  'ard',
#  'babe,',
#  'believe',
#  'bonus',
#  'collect',
#  'details',
#  'drive',
#  'either',
#  'enough',
#  'free!',
#  'good.',
#  'hour',
#  'network',
#  'ringtone',
#  'room',
#  'sat',
#  'set',
#  'sexy',
#  'shit',
#  'tones',
#  'tried',
#  "won't",
#  '4*',
#  '500',
#  'bus',
#  'cause',
#  'coz',
#  'do.',
#  'finished',
#  'gift',
#  'hot',
#  'house',
#  'liao...',
#  'me?',
#  'post',
#  'saw',
#  'show',
#  'sir,',
#  'start',
#  'stay',
#  'stop.',
#  't&cs',
#  "there's",
#  'these',
#  'town',
#  'tv',
#  "we're",
#  "what's",
#  'wot',
#  'xmas',
#  'yet',
#  '08000839402',
#  '150p',
#  '16',
#  '8007',
#  '86688',
#  'address',
#  'away',
#  'book',
#  'close',
#  'code',
#  'early',
#  'feeling',
#  'forget',
#  'full',
#  'goin',
#  'guaranteed.',
#  'guy',
#  'hair',
#  'havent',
#  'later.',
#  'mail',
#  'making',
#  'missing',
#  'music',
#  'needs',
#  'plan',
#  'pounds',
#  'price',
#  're',
#  "she's",
#  'takes',
#  'texts',
#  'today?',
#  'todays',
#  'together',
#  'too.',
#  'u!',
#  'wants',
#  "we'll",
#  'wen',
#  'wid',
#  'yeah,',
#  'years',
#  'å£2000',
#  '7',
#  '750',
#  ':-)',
#  'aft',
#  'aight',
#  'already?',
#  'await',
#  'baby',
#  'bed',
#  'both',
#  'calling',
#  'comes',
#  'decided',
#  'evening',
#  'expires',
#  'hello',
#  'it,',
#  'kind',
#  'land',
#  'line.',
#  'lose',
#  'lots',
#  'message.',
#  'missed',
#  'mobileupd8',
#  'month',
#  'neva',
#  'offer',
#  'pain',
#  'pics',
#  'plz',
#  'princess!',
#  'right?',
#  'ring',
#  'saying',
#  'secret',
#  'smoke',
#  'sounds',
#  'started',
#  'taking',
#  'tmr',
#  'tomorrow.',
#  'tonight?',
#  'top',
#  'trip',
#  'type',
#  'unsubscribe',
#  'up.',
#  'update',
#  'vouchers',
#  'walk',
#  'week.',
#  'wit',
#  'work.',
#  '12hrs',
#  'anyway',
#  'apply',
#  'available',
#  'beautiful',
#  'calls',
#  'carlos',
#  'change',
#  'congratulations',
#  'date',
#  'dating',
#  "doesn't",
#  'drop',
#  'fine',
#  "haven't",
#  'head',
#  'hours',
#  'identifier',
#  'important',
#  'it?',
#  'juz',
#  'lar...',
#  'leaving',
#  'lucky',
#  'mean',
#  'messages',
#  'mob',
#  'oh.',
#  'only.',
#  'out.',
#  'points.',
#  'question',
#  's',
#  'school',
#  'sister',
#  'telling',
#  'test',
#  'th',
#  'thanx',
#  'thinking',
#  'tot',
#  'å£500',
#  'å£5000',
#  '&lt;decimal&gt;',
#  'already.',
#  'alright',
#  'answer',
#  'bank',
#  'bored',
#  'break',
#  'caller',
#  'care.',
#  'collection.',
#  'company',
#  'drink',
#  'each',
#  'fancy',
#  'final',
#  'fr',
#  'gr8',
#  'her.',
#  'hold',
#  'id',
#  'it!',
#  'knew',
#  'landline.',
#  'least',
#  'lets',
#  'line',
#  'lovely',
#  'nite',
#  'noe',
#  'now,',
#  'oso',
#  'private!',
#  'problem',
#  'search',
#  'shop',
#  'somebody',
#  'statement',
#  't&c',
#  'thinks',
#  'true',
#  'visit',
#  'weekend',
#  'wonderful',
#  'yourself',
#  'å£1.50',
#  '10',
#  '10p',
#  '18+',
#  '2.',
#  '2003',
#  '4.',
#  '800',
#  '87066',
#  'ah?',
#  'angry',
#  'anytime',
#  'back.',
#  'bout',
#  'busy',
#  'checking',
#  'choose',
#  'class.',
#  'code:',
#  'colour',
#  'cool,',
#  'currently',
#  'delivery',
#  'driving',
#  'easy',
#  'easy,',
#  'empty',
#  'eve',
#  'everyone',
#  'fone',
#  'food',
#  'found',
#  'frm',
#  'frnd',
#  'g',
#  'gone',
#  'hard',
#  'hows',
#  'know.',
#  'landline',
#  'loads',
#  'me,',
#  'morning.',
#  'movie',
#  'mu',
#  'national',
#  'no:',
#  'office',
#  'operator',
#  'opt',
#  'order',
#  'outside',
#  'pa.',
#  'pobox',
#  'poly',
#  'prize.',
#  'rate',
#  'sad',
#  'sae',
#  'sch',
#  'sex',
#  'story',
#  'their',
#  'this.',
#  'though',
#  'un-redeemed',
#  'urgent',
#  'used',
#  'valued',
#  'week!',
#  'yes,',
#  '!!',
#  '..',
#  '08000930705',
#  '8',
#  ':-(',
#  'abiola',
#  'afternoon',
#  'alone',
#  'already...',
#  'apply.',
#  'askd',
#  'b4',
#  'bath',
#  'brother',
#  'club',
#  'cool.',
#  'darren',
#  'dear.',
#  'dnt',
#  'email',
#  'entered',
#  'extra',
#  'felt',
#  'finally',
#  'fine.',
#  'free.',
#  'fucking',
#  'gotta',
#  'great!',
#  'great.',
#  'ha',
#  'happen',
#  'help.',
#  'hurt',
#  "i'd",
#  'in.',
#  'invited',
#  'k,',
#  'leh...',
#  'log',
#  'lost',
#  'me..',
#  'mine',
#  'mm',
#  'month.',
#  'msgs',
#  'mum',
#  'myself',
#  'nt',
#  'ok?',
#  'okay',
#  'one.',
#  'open',
#  'pass',
#  'poor',
#  'project',
#  'second',
#  'seeing',
#  'sell',
#  'services',
#  'she.s',
#  'sis',
#  'sleeping',
#  'st',
#  'starts',
#  'sun',
#  'support',
#  'touch',
#  'txts',
#  'u,',
#  'w',
#  'weeks',
#  'wil',
#  'wkly',
#  'words',
#  'worry',
#  'worth',
#  'write',
#  'xx',
#  'yar',
#  'yesterday',
#  'yours.',
#  '\x89û_',
#  'å£2,000',
#  'å£250',
#  '1.',
#  '100',
#  '3.',
#  '=',
#  'age',
#  'aight,',
#  'area',
#  'award.',
#  'awesome,',
#  'booked',
#  'call.',
#  'callertune',
#  'catch',
#  'cd',
#  'charged',
#  'chennai',
#  'college',
#  'complimentary',
#  'convey',
#  'couple',
#  'crazy',
#  'darlin',
#  'de',
#  'difficult',
#  'doin',
#  'don',
#  'dream',
#  'else',
#  'family',
#  'feels',
#  'friendship',
#  'frnds',
#  'gas',
#  'girls',
#  'haha...',
#  'happened',
#  'heard',
#  'hit',
#  'however',
#  'huh',
#  "joy's",
#  'kiss',
#  'knows',
#  'life.',
#  'light',
#  'love.',
#  'match',
#  'mayb',
#  'medical',
#  'min.',
#  'night.',
#  'night?',
#  'normal',
#  'number.',
#  'numbers',
#  'o',
#  'ok,',
#  'old',
#  'pa',
#  'party',
#  'pic',
#  'pm',
#  'prize!',
#  'rates',
#  'reached',
#  'read',
#  'reading',
#  'reason',
#  'rply',
#  's.',
#  'safe',
#  'seen',
#  'simple..',
#  'song',
#  'sorry.',
#  'swing',
#  'ten',
#  'thanx...',
#  'then.',
#  'thinkin',
#  'through',
#  'times',
#  'tired',
#  'took',
#  'train',
#  'treat',
#  'truth',
#  'wat...',
#  'wat?',
#  'well,',
#  'well.',
#  'whats',
#  'whenever',
#  'wine',
#  'within',
#  'year.',
#  'yet.',
#  'yr',
#  '&lt;time&gt;',
#  '*grins*',
#  '0800',
#  '11',
#  '150p/msg',
#  ':',
#  'admirer',
#  'again!',
#  'again.',
#  'against',
#  'ans',
#  'asking',
#  'auction',
#  'bluetooth',
#  'boytoy',
#  'case',
#  'charge',
#  'charity',
#  'comp',
#  'completely',
#  'computer',
#  'congrats!',
#  'content',
#  'cool',
#  'copy',
#  'cum',
#  'cut',
#  'day,',
#  'decide',
#  'del',
#  'din',
#  'direct',
#  'dogging',
#  'doing.',
#  'doing?',
#  'dreams',
#  'dude',
#  'eg',
#  'eh',
#  'em',
#  'enter',
#  'exam',
#  'far',
#  'film',
#  'fine,',
#  'following',
#  'gave',
#  ...]

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
train_iter, test_iter = ttd.Iterator.splits(
    (train_dataset,test_dataset), sort_key = lambda x: len(x.data),
    batch_sizes = (32, 256), device=device
)

# %%
for inputs, targets in train_iter:
    print("inputs", inputs, "shape", inputs.shape)
    # for input in inputs:
    #     print(index_to_token(vocab.itos,input))
    print("targets", inputs, "shape", targets.shape)
    break
# Out:
# inputs tensor([[   1,    1,    1,  ...,   50,   30, 5276],
#         [   1,    1,    1,  ...,   51,    2,  490],
#         [   1,    1,    1,  ...,    3,  203, 1007],
#         ...,
#         [   1,    1,    1,  ...,   59,  105, 1475],
#         [   1,    1,    1,  ..., 2379,   12, 3006],
#         [   1,    1,    1,  ...,    7,  242, 1007]], device='cuda:0') shape torch.Size([32, 32])
# targets tensor([[   1,    1,    1,  ...,   50,   30, 5276],
#         [   1,    1,    1,  ...,   51,    2,  490],
#         [   1,    1,    1,  ...,    3,  203, 1007],
#         ...,
#         [   1,    1,    1,  ...,   59,  105, 1475],
#         [   1,    1,    1,  ..., 2379,   12, 3006],
#         [   1,    1,    1,  ...,    7,  242, 1007]], device='cuda:0') shape torch.Size([32])

# %%
for inputs, targets in test_iter:
    print("inputs", inputs, "shape", inputs.shape)
    # for input in inputs:
    #     print(index_to_token(vocab.itos,input))
    print("targets", inputs, "shape", targets.shape)
    break
# Out:
# inputs tensor([[2809,   19,    0, 1693, 9292, 4231],
#         [   3,   64,    6, 8900,    0,  280],
#         [ 127,   59, 1208,  175,    0,  762],
#         ...,
#         [   1,    1,    1,    1,    1,    0],
#         [   1,    1,    1,    1,    1,   79],
#         [   1,    1,    1,    1,    1,  334]], device='cuda:0') shape torch.Size([256, 6])
# targets tensor([[2809,   19,    0, 1693, 9292, 4231],
#         [   3,   64,    6, 8900,    0,  280],
#         [ 127,   59, 1208,  175,    0,  762],
#         ...,
#         [   1,    1,    1,    1,    1,    0],
#         [   1,    1,    1,    1,    1,   79],
#         [   1,    1,    1,    1,    1,  334]], device='cuda:0') shape torch.Size([256])

# %% [markdown]
# ### Create and train model

# %%
model,train_losses, test_losses = create_model_and_train(train_iter,test_iter,V=len(vocab),D=20,M=15,L=1,K=1,n_epochs=50,model_type="LSTM")
# Out:
# cuda:0
# Epoch 5/50, Train Loss: 0.1263, Test Loss: 0.1978
# Epoch 10/50, Train Loss: 0.0410, Test Loss: 0.1636
# Epoch 15/50, Train Loss: 0.0226, Test Loss: 0.1685
# Epoch 20/50, Train Loss: 0.0146, Test Loss: 0.1721
# Epoch 25/50, Train Loss: 0.0100, Test Loss: 0.1897
# Epoch 30/50, Train Loss: 0.0064, Test Loss: 0.2030
# Epoch 35/50, Train Loss: 0.0051, Test Loss: 0.2166
# Epoch 40/50, Train Loss: 0.0047, Test Loss: 0.2185
# Epoch 45/50, Train Loss: 0.0031, Test Loss: 0.2084
# Epoch 50/50, Train Loss: 0.0022, Test Loss: 0.2052

# %%
plot_metric(train_losses, "train loss")
plot_metric(test_losses, "test loss")

# %%
acc_train, y_train, p_train = acc_compouter(model,device,train_iter)
print(acc_train)
# Out:
# 0.9994871794871795

# %%
acc_test, y_test, p_test = acc_compouter(model,device,test_iter)
print(acc_test)
# Out:
# 0.9647129186602871

# %%
df[df["labels"] == "spam"].size / df.size
# Out:
# 0.13406317300789664

# %%
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, [0,1])
# Out:
# Confusion matrix, without normalization
# [[1442    8]
#  [  51  171]]

# %%
cm = confusion_matrix(y_train, p_train)
plot_confusion_matrix(cm, [0,1])
# Out:
# Confusion matrix, without normalization
# [[3375    0]
#  [   2  523]]

# %%
small_sample = df[df.labels=="spam"].sample(3)
small_sample
# Out:
#      labels                                               data  b_labels
# 2310   spam  You have won a Nokia 7250i. This is what you g...         1
# 400    spam  FREE RINGTONE text FIRST to 87131 for a poly o...         1
# 2619   spam  <Forwarded from 21870000>Hi - this is your Mai...         1

# %%
with open("sample_test.csv", "w") as f:
    f.write("data\n")
    for i, row in small_sample.iterrows():
        f.write(row["data"] + "\n")

# %%
sample_dataset = ttd.TabularDataset(
    path = 'sample_test.csv',
    format = 'csv',
    skip_header = True,
    fields = [('data',TEXT)]
)

# %%
sample_iter = ttd.Iterator(
    sample_dataset, sort_key = lambda x: len(x.data),
    batch_size = 32, device=device
)

# %%
for inputs in sample_iter:
    print("inputs:", inputs)

    outputs = model(inputs.data)

    print(outputs)
# Out:
# inputs:
# [torchtext.legacy.data.batch.Batch of size 3]
# 	[.data]:[torch.cuda.LongTensor of size 3x28 (GPU 0)]
# tensor([[7.2086],
#         [7.7625],
#         [7.7654]], device='cuda:0', grad_fn=<AddmmBackward>)

# %%
single_sentence = "Our dating service has been asked 2 contact U by someone shy! CALL 090503303 NOW and all will be revealed."

# %%
TEXT.preprocess(single_sentence)
# Out:
# ['our',
#  'dating',
#  'service',
#  'has',
#  'been',
#  'asked',
#  '2',
#  'contact',
#  'u',
#  'by',
#  'someone',
#  'shy!',
#  'call',
#  '090503303',
#  'now',
#  'and',
#  'all',
#  'will',
#  'be',
#  'revealed.']

# %%
TEXT.numericalize([TEXT.preprocess(single_sentence)])
# Out:
# tensor([[  77,  622,  228,   91,   90,  322,   22,  148,    7,   68,  221, 9497,
#            17,    0,   45,    8,   44,   34,   36, 1436]])

# %%
toks = TEXT.preprocess(single_sentence)
sent_idx = TEXT.numericalize([toks])

model(sent_idx.to(device))
# Out:
# tensor([[6.0398]], device='cuda:0', grad_fn=<AddmmBackward>)
